# %%
import pandas as pd
import folium

# %%
routes = pd.read_csv("../data/raw/20250518/routes.txt")
shapes = pd.read_csv("../data/raw/20250518/shapes.txt")
trips = pd.read_csv("../data/raw/20250518/trips.txt")
stops = pd.read_csv("../data/raw/20250518/stops.txt")
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_5112\808438327.py:3: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   trips = pd.read_csv("../data/raw/20250518/trips.txt")

# %%
routes.head()
# Out:
#   agency_id route_id route_short_name  route_long_name  route_type  \
# 0       BKK     0050                5              NaN           3
# 1       BKK     0070                7              NaN           3
# 2       BKK     0075               7E              NaN           3
# 3       BKK     0078               7G              NaN           3
# 4       BKK     0085               8E              NaN           3
#
#                                           route_desc route_color  \
# 0           Pasaréti tér / Rákospalota, Kossuth utca      009EE3
# 1  Albertfalva vasútállomás / Újpalota, Nyírpalot...      009EE3
# 2        Blaha Lujza tér M / Újpalota, Nyírpalota út      009EE3
# 3  Cinkotai autóbuszgarázs / Újpalota, Nyírpalota út      009EE3
# 4  Kelenföld vasútállomás M / Újpalota, Nyírpalot...      009EE3
#
#   route_text_color  route_sort_order
# 0           FFFFFF                20
# 1           FFFFFF                24
# 2           FFFFFF                25
# 3           FFFFFF                26
# 4           FFFFFF                27

# %%
route_id = routes[routes.route_short_name == '5'].route_id.unique()
route_id
# Out:
# array(['0050'], dtype=object)

# %%
trips.head()
# Out:
#   route_id   trip_id        service_id            trip_headsign  direction_id  \
# 0     8140  C0418310  C04183AHPMAA-011  Soroksár, Molnár-sziget             0
# 1     8140  C0418311  C04183AHPMAA-011        Csepel-Királyerdő             1
# 2     8140  C0418312  C04183AHPMAA-011  Soroksár, Molnár-sziget             0
# 3     8140  C0418313  C04183AHPMAA-011        Csepel-Királyerdő             1
# 4     8140  C0418314  C04183AHPMAA-011  Soroksár, Molnár-sziget             0
#
#           block_id shape_id  wheelchair_accessible  bikes_allowed
# 0  C04183_8140_1_5     Y701                    1.0            1.0
# 1  C04183_8140_1_6     Y702                    1.0            1.0
# 2  C04183_8140_1_7     Y701                    1.0            1.0
# 3  C04183_8140_1_8     Y702                    1.0            1.0
# 4  C04183_8140_1_9     Y701                    1.0            1.0

# %%
shape_ids =trips[trips.route_id == route_id[0]].shape_id.unique()
shape_ids
# Out:
# array(['VI96', 'VI95'], dtype=object)

# %%
shapes.head()
# Out:
#   shape_id  shape_pt_sequence  shape_pt_lat  shape_pt_lon  shape_dist_traveled
# 0     0976              11323     47.474042     19.046862                  0.0
# 1     0976              11324     47.474061     19.046866                  2.0
# 2     0976              11325     47.474015     19.047305                 35.0
# 3     0976              11326     47.473975     19.047649                 61.0
# 4     0976              11327     47.473891     19.048431                121.0

# %%
shapes[shapes.shape_id.isin(shape_ids)]
# Out:
#        shape_id  shape_pt_sequence  shape_pt_lat  shape_pt_lon  \
# 490233     VI95             181446     47.523609     18.994082
# 490234     VI95             181447     47.523671     18.994152
# 490235     VI95             181448     47.523492     18.994500
# 490236     VI95             181449     47.523348     18.994793
# 490237     VI95             181450     47.523026     18.995455
# ...         ...                ...           ...           ...
# 491754     VI96             181183     47.523026     18.995455
# 491755     VI96             181184     47.523348     18.994793
# 491756     VI96             181185     47.523492     18.994500
# 491757     VI96             181186     47.523620     18.994250
# 491758     VI96             181187     47.523636     18.994268
#
#         shape_dist_traveled
# 490233                  0.0
# 490234                  7.0
# 490235                 40.0
# 490236                 67.0
# 490237                128.0
# ...                     ...
# 491754              18800.0
# 491755              18861.0
# 491756              18888.0
# 491757              18912.0
# 491758              18917.0
#
# [1526 rows x 5 columns]

# %%
def get_route_data(route_short_name):
    route_short_name = str(route_short_name)
    route_id = routes[routes.route_short_name == route_short_name].route_id.unique()
    #print('route_id:', route_id)
    shape_ids = trips[trips.route_id == route_id[0]].shape_id.unique()

    shape_counts = trips[trips.route_id == route_id[0]].shape_id.value_counts()
    #print(shape_counts)
    #print(shape_counts[:2].index)
    #print(type(shape_counts[:2]))
    shape_ids = shape_counts[:2].index
    
    #print('shape_ids:',shape_ids)
    route_shapes = shapes[shapes.shape_id.isin(shape_ids)]
    return route_shapes

# %%
route_shapes = get_route_data('1A')
route_shapes
# Out:
#        shape_id  shape_pt_sequence  shape_pt_lat  shape_pt_lon  \
# 599806     YJ24             186291     47.476325     19.099294
# 599807     YJ24             186292     47.476320     19.099309
# 599808     YJ24             186293     47.476353     19.099334
# 599809     YJ24             186294     47.476462     19.099416
# 599810     YJ24             186295     47.476623     19.099516
# ...         ...                ...           ...           ...
# 600492     YJ25             187757     47.476650     19.099419
# 600493     YJ25             187758     47.476498     19.099323
# 600494     YJ25             187759     47.476370     19.099228
# 600495     YJ25             187760     47.475903     19.098867
# 600496     YJ25             187761     47.475893     19.098895
#
#         shape_dist_traveled
# 599806                  0.0
# 599807                  1.0
# 599808                  5.0
# 599809                 19.0
# 599810                 38.0
# ...                     ...
# 600492              11156.0
# 600493              11174.0
# 600494              11190.0
# 600495              11249.0
# 600496              11252.0
#
# [691 rows x 5 columns]

# %%
def vizualize_route(route_short_name):
    shape_points = get_route_data(route_short_name)
    #print(shape_points)

    # térkép középpontja (első pont)
    #center = [shape_points['shape_pt_lat'].iloc[0], shape_points['shape_pt_lon'].iloc[0]]
    center = [shape_points['shape_pt_lat'].mean(), shape_points['shape_pt_lon'].mean()]

    m = folium.Map(location=center, zoom_start=11)

    # vonal kirajzolása
    coords = list(zip(shape_points['shape_pt_lat'], shape_points['shape_pt_lon']))
    folium.PolyLine(coords, color="blue", weight=4.5, opacity=0.8).add_to(m)

    return m  # notebookban megjelenik

# %%
vizualize_route('41')
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4c2c629008db5a8ecf9af351f108bf2e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4c2c629008db5a8ecf9af351f108bf2e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4c2c629008db5a8ecf9af351f108bf2e = L.map(
#                 &quot;map_4c2c629008db5a8ecf9af351f108bf2e&quot;,
#                 {
#                     center: [47.482178466359976, 19.033358541115582],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_fe5b13c8c784b74832e7848f603e7dc3 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_4c2c629008db5a8ecf9af351f108bf2e);
#
#
#             var poly_line_89bb46d690d48a54a7c1698ab027efa1 = L.polyline(
#                 [[47.548489, 19.029018], [47.548137, 19.029007], [47.548045, 19.029004], [47.548001, 19.029002], [47.547953, 19.029001], [47.54778, 19.028995], [47.54757, 19.029006], [47.547441, 19.029008], [47.547359, 19.029011], [47.547255, 19.029022], [47.547071, 19.029043], [47.546837, 19.029109], [47.546718, 19.029141], [47.545965, 19.029338], [47.545569, 19.029441], [47.545255, 19.029541], [47.54514, 19.029576], [47.545118, 19.029583], [47.544604, 19.029694], [47.544165, 19